# %%
import os
import pandas as pd
import numpy as np
from numpy.linalg import eig
import xarray as xr
from sklearn_xarray import wrap, Target
from sklearn.decomposition import PCA, KernelPCA
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import seaborn as sns

# %%
DatosMes = pd.read_csv("D:\DOCS\PATIA\PromMeses.csv")

# %%
DatosMes
# Out:
#           Fecha          x         y     VALOR  Meses  Anios
# 0    2001-01-31 -77.208440  1.591855  0.635868      1   2001
# 1    2001-02-28 -77.208336  1.597052  0.611741      2   2001
# 2    2001-03-31 -77.199728  1.607479  0.530273      3   2001
# 3    2001-04-30 -77.209002  1.592161  0.612589      4   2001
# 4    2001-05-31 -77.205535  1.602879  0.537826      5   2001
# ..          ...        ...       ...       ...    ...    ...
# 247  2021-08-31 -77.207843  1.591533  0.510306      8   2021
# 248  2021-09-30 -77.227000  1.577095  0.470451      9   2021
# 249  2021-10-31 -77.211011  1.584244  0.511375     10   2021
# 250  2021-11-30 -77.208961  1.592430  0.594285     11   2021
# 251  2021-12-31 -77.206938  1.624222  0.588580     12   2021
#
# [252 rows x 6 columns]

# %%
DatosMes.set_index("Fecha", inplace=True)

# %%
DatosMes
# Out:
#                     x         y     VALOR  Meses  Anios
# Fecha
# 2001-01-31 -77.208440  1.591855  0.635868      1   2001
# 2001-02-28 -77.208336  1.597052  0.611741      2   2001
# 2001-03-31 -77.199728  1.607479  0.530273      3   2001
# 2001-04-30 -77.209002  1.592161  0.612589      4   2001
# 2001-05-31 -77.205535  1.602879  0.537826      5   2001
# ...               ...       ...       ...    ...    ...
# 2021-08-31 -77.207843  1.591533  0.510306      8   2021
# 2021-09-30 -77.227000  1.577095  0.470451      9   2021
# 2021-10-31 -77.211011  1.584244  0.511375     10   2021
# 2021-11-30 -77.208961  1.592430  0.594285     11   2021
# 2021-12-31 -77.206938  1.624222  0.588580     12   2021
#
# [252 rows x 5 columns]

# %%
DatosMes["VALOR"].plot(label="VHI mensual",figsize=(16, 8))
plt.xticks(rotation=90)
plt.show()

# %%
a = np.array([[2, 2, 4], 
              [1, 3, 5],
              [2, 3, 4]])

# %%
a
# Out:
# array([[2, 2, 4],
#        [1, 3, 5],
#        [2, 3, 4]])

# %%
plt.plot(a[0], label="0")
plt.plot(a[1], label="1")
plt.plot(a[2], label="2")
plt.legend()
plt.show()

# %%
w,v=eig(a)
print('E-value:', w)
print('E-vector', v)
# Out:
# E-value: [ 8.80916362  0.92620912 -0.73537273]
# E-vector [[-0.52799324 -0.77557092 -0.36272811]
#  [-0.604391    0.62277013 -0.7103262 ]
#  [-0.59660259 -0.10318482  0.60321224]]

# %%
plt.plot(w)

# %%
plt.plot(v)
# Out:
# [<matplotlib.lines.Line2D at 0x1c91cae9b80>,
#  <matplotlib.lines.Line2D at 0x1c91cadbc70>,
#  <matplotlib.lines.Line2D at 0x1c91cadbca0>]
